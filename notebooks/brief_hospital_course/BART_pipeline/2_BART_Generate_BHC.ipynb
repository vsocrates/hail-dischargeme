# %%
split = "valid"
version = "v1"

inputcol = "bhc_preceding_text"
outputcol = "brief_hospital_course"

# %%
import datasets
from transformers import pipeline
from transformers.pipelines.pt_utils import KeyDataset
from tqdm.auto import tqdm
from pathlib import Path

# %%
pipe = pipeline("text2text-generation", model="/home/vs428/Documents/DischargeMe/hail-dischargeme/notebooks/brief_hospital_course/template_code/bart-dischargeme-results_v2/checkpoint-16500", device=0)

# %%
from pynvml import *


def print_gpu_utilization():
    nvmlInit()
    handle = nvmlDeviceGetHandleByIndex(0)
    info = nvmlDeviceGetMemoryInfo(handle)
    print(f"GPU memory occupied: {info.used//1024**2} MB.", flush=True)


def print_summary(result):
    print(f"Time: {result.metrics['train_runtime']:.2f}", flush=True)
    print(f"Samples/second: {result.metrics['train_samples_per_second']:.2f}", flush=True)
    print_gpu_utilization()

# %% [markdown]
# ## Data
#
# ---

# %%
import pandas as pd
from datasets import Dataset

# %%
print_gpu_utilization()
# Out:
# GPU memory occupied: 2139 MB.

# %%
if split == "valid":
    fname = "/gpfs/gibbs/project/rtaylor/shared/DischargeMe/public/valid/discharge_target_with_preceding_text+structured_data.pickle"
elif split == "test_phase_1":
    fname = "/gpfs/gibbs/project/rtaylor/shared/DischargeMe/public/test/discharge_target_with_preceding_text+structured_data.pickle"
else:
    raise Exception("Split doesn't exist!")

# %%
data = pd.read_pickle(fname)
ds = Dataset.from_pandas(data[['hadm_id', inputcol, outputcol]], split="test")

# %%
data[f'{outputcol}_word_count'].describe()
# Out:
# count    14719.000000
# mean       325.122495
# std        238.098437
# min         10.000000
# 25%        160.000000
# 50%        278.000000
# 75%        439.000000
# max       4414.000000
# Name: brief_hospital_course_word_count, dtype: float64

# %%
ds

# %%
BATCH_SIZE = 16

# %%
# %%time
# KeyDataset (only *pt*) will simply return the item in the dict returned by the dataset item
# as we're not interested in the *target* part of the dataset. For sentence pair use KeyPairDataset
outs = []
for idx, out in enumerate(pipe(KeyDataset(ds, inputcol), 
                     batch_size=BATCH_SIZE,
                     clean_up_tokenization_spaces=True,
                     truncation=True,
                     return_text=True,
                     max_length=1028,
                     no_repeat_ngram_size=5, 
                     num_beams=3, 
                     early_stopping=True
                    )):
    print(f"{idx}/920")
    outs.append(out)

# %%
print_gpu_utilization()

# %%
def flatten(xss):
    return [x for xs in xss for x in xs]

# %%
outs = flatten(outs)

# %%
data_out = pd.concat([data, pd.DataFrame.from_records(outs).rename({"generated_text": f"{outputcol}_BART"}, axis=1)], axis=1)

# %%
# print("Writing file to:")
# print(f"/home/vs428/Documents/DischargeMe/hail-dischargeme/notebooks/brief_hospital_course/outputs/bhc_scores/{Path(fname).stem}_BART_gen_{version}.pickle")
# data_out.to_pickle(f"/home/vs428/Documents/DischargeMe/hail-dischargeme/notebooks/brief_hospital_course/outputs/bhc_scores/{Path(fname).stem}_BART_gen_{version}.pickle")

# %% [markdown]
# # Check results

# %%
import pandas as pd

# %%
data_out = pd.read_pickle("/home/vs428/Documents/DischargeMe/hail-dischargeme/notebooks/brief_hospital_course/outputs/bhc_scores/discharge_target_with_preceding_text+structured_data_BART_gen_test_phase_1_v3.pickle")

# %%
data_out[[f"{outputcol}_BART", outputcol]]
# Out:
#                               brief_hospital_course_BART  \
# 0      ___ with PMH HCV, ETOH cirrhosis with ascites,...
# 1      ___ yo F s/p L4-5 discectomy/fusion (___) by \...
# 2      The patient was admitted to the colorectal \ns...
# 3      ___ w/ h/o CAD (known 3VD) and ESRD on HD, \nw...
# 4      Mr. ___ is a ___ year old man with a history o...
# ...                                                  ...
# 14697  ___ M PMHx dilated non-ischemic cardiomyopathy...
# 14698  ___ year old M with PMH of CAD s/p 2xMI and co...
# 14699  ___ with CHF (EF 60%), a-fib on coumadin, \nHT...
# 14700  This is a ___ with PMHx of hypertension and \n...
# 14701  Mr. ___ is a ___ y/o male with a history of ID...
#
#                                    brief_hospital_course
# 0      ___ with PMH HCV, ETOH cirrhosis with ascites,...
# 1      ___ yo F with recent lumbar laminectomy c/b MS...
# 2      The patient was seen ___ the emergency departm...
# 3      Ms. ___ is a ___ woman with a history of T2DM,...
# 4      ___ with IDDM and h/o provoked PE on apixiban ...
# ...                                                  ...
# 14697  ___ M PMHx dilated non-ischemic cardiomyopathy...
# 14698  Mr. ___ is a ___ year-old man with CAD, HTN, H...
# 14699  ___ year old female with past medical history ...
# 14700  Mr. ___ is a ___ male with a past medical hist...
# 14701  Mr. ___ is a ___ year old male with a history ...
#
# [14702 rows x 2 columns]

# %% [markdown]
# # Scoring

# %%
import sys
sys.path.insert(0,"../../../scoring")

# %%
from scoring_bhc import calculate_scores_bhc
from scoring_bhc import compute_overall_score_bhc

# %%
from scoring_instructions import calculate_scores_instructions
from scoring_instructions import compute_overall_score_instructions

# %%
# This assumes that the output from BART has the column outputcol_BART (i.e. brief_hospital_course_BART)
bart_results = data_out[~data_out[f'{outputcol}_BART'].isna()]

# %%
print(bart_results['bhc_preceding_text'].sample(1).squeeze())
# Out:
#
# Name:  ___                  Unit No:   ___
#
# Admission Date:  ___              Discharge Date:   ___
#
# Date of Birth:  ___             Sex:   F
#
# Service: MEDICINE
#
# Allergies:
# No Known Allergies / Adverse Drug Reactions
#
# Attending: ___
#
# Chief Complaint:
# Ascites and lower extremity edema
#
# Major Surgical or Invasive Procedure:
# Abdominal paracentesis ___ (2L removed) and ___ (2L
# removed)
#
#
# History of Present Illness:
# ___ w/ HBV/HCV cirrhosis, HTN, DM who presented from her ___
# clinic for worsening ascites and PCP concern for SBP. She was
# discharged from ___ on ___ after being admitted for a similar
# presentation. During that admission she had a 3L paracentesis
# and her diuretics were uptitrated at that time. She reports that
# her ascites has steadily worsened since discharge. Pt denies
# dietary salt indiscretion. She called her doctor on ___ who
# wanted to increase diuretics, but wanted to get blood work
# first. She followed up with her PCP today, who told her to come
# to ___ for a tap. Denied abdominal pain, fevers, chills,
# vomiting. Endorses intermittent nausea, worsening shortness of
# breath over the last week (can now only walk about 100 steps),
# and new bilateral leg pain that the ___ attributed to the
# swelling.
#
# In the ED, initial vitals were: 98.7, 87, 143/74, 18, 97% RA
# ___ received diagnostic paracentesis in the ED.
# Vitals prior to transfer were: 98.5, 84, 138/71, 17, 99% RA
# On the floor, ___ reported that she feels well and had no
# complaints.
#
#
# Past Medical History:
# # Hepatic Cirrhosis
# + Hepatitis B and Hepatitis C (genotype 3a)
# + s/p liver biopsy ___ (___) c/w cirrhosis
# + With evidence of hepatic encephalopathy, ascites
# + No esophageal or gastric varices (EGD ___ at ___
# ___
# # HTN
# # Hyperlipidemia
# # Mild pHTN
# # OSA on CPAP
# # Diabetes Mellitus
# + c/b peripheral neuropathy
# # depression
# # h/o IVDU on methadone
#
# Social History:
# ___
# Family History:
# Negative for liver disease.
#
# Physical Exam:
# Admission physical exam
# VS: 97.7, 137/60, 86, 20, 98%RA
# ___: fatigued appearing Hispanic female in NAD
# HEENT: NCAT, sclerae slightly icteric. PERRL, EOMI. OP clear
# with poor dentition
# Neck: supple, no ___, no thyromegaly
# CV: RRR, normal s1/s2. ___ systolic murmur heard best at the
# LUSB. No rubs or gallops
# Lungs: CTAB, no w/r/r
# Abdomen: Distended. Not able to appreciate bowel sounds.
# Nontender to palpation. Some ecchymoses periumbilically ___ to
# old heparin shots.
# GU: no foley
# Ext: WWP, pulses 2+ DP. No cyanosis/clubbing. Significant
# dependent edema to just below the knee bilaterally and affecting
# the upper thighs posteriorly
# Neuro: CN ___ grossly intact. Moving all 4 extremities with
# purpose. No asterixis
# Skin: No jaundice.
#
# Discharge physical exam
# Vitals- Tc: 98.6  BP 115/52 HR 67  RR 20 100% on RA
# ___- Alert, oriented, no acute distress and less distended
# abdomen
# HEENT- Sclera slightly icteric, dry oral mucosa, oropharynx
# clear,
# Neck- supple, JVP not elevated, no LAD
# Lungs- Clear to auscultation bilaterally, no wheezes, rales,
# ronchi
# CV- Regular rate and rhythm, normal S1 + S2, I/VI systolic
# murmur, no rubs, gallops
# Abdomen- tight, ___, less distended than ___, bowel
# sounds present, no rebound tenderness or guarding,
# GU- no foley
# Ext- warm, well perfused, 2+ pulses, 2+ edema to thighs (tender
# to palpation)
# Neuro- ___ intact, motor function grossly normal, asterixis
# positive.
#
#
# Pertinent Results:
# Admission labs
# ___ 12:13AM BLOOD ___
# ___ Plt ___
# ___ 12:13AM BLOOD ___ ___
# ___ 12:13AM BLOOD ___
# ___
# ___ 12:13AM BLOOD ___
# ___ 12:13AM BLOOD ___
#
# Discharge labs
# ___ 08:10AM BLOOD ___
# ___ Plt ___
# ___ 08:10AM BLOOD ___ ___
# ___ 08:10AM BLOOD ___
# ___
# ___ 08:10AM BLOOD ___
# ___ 08:10AM BLOOD ___
#
# Imaging:
# Liver ultrasound
# IMPRESSION:
# 1. Coarsened and nodular liver echotexture in keeping with known
# diagnosis of cirrhosis.  No focal liver masses identified.
# 2. Moderate amount of ascites.
# 3. Cholelithiasis without evidence of cholecystitis.
# 4. Splenomegaly

# %%
reference = bart_results[['hadm_id', outputcol]]
generated = bart_results[['hadm_id', f"{outputcol}_BART"]].rename({f"{outputcol}_BART":outputcol}, axis=1)

# %%
scores = calculate_scores_bhc(generated,
                 reference,
                 [
                     # "bleu", 
                  "rouge",
                     # "bertscore",
                     # "meteor"
                 ])
# Out:
# Beginning scoring...
# rougeScorer initialized
# Processed 128/14702 samples.
# Processed 256/14702 samples.
# Processed 384/14702 samples.
# Processed 512/14702 samples.
# Processed 640/14702 samples.
# Processed 768/14702 samples.
# Processed 896/14702 samples.
# Processed 1024/14702 samples.
# Processed 1152/14702 samples.
# Processed 1280/14702 samples.
# Processed 1408/14702 samples.
# Processed 1536/14702 samples.
# Processed 1664/14702 samples.
# Processed 1792/14702 samples.
# Processed 1920/14702 samples.
# Processed 2048/14702 samples.
# Processed 2176/14702 samples.
# Processed 2304/14702 samples.
# Processed 2432/14702 samples.
# Processed 2560/14702 samples.
# Processed 2688/14702 samples.
# Processed 2816/14702 samples.
# Processed 2944/14702 samples.
# Processed 3072/14702 samples.
# Processed 3200/14702 samples.
# Processed 3328/14702 samples.
# Processed 3456/14702 samples.
# Processed 3584/14702 samples.
# Processed 3712/14702 samples.
# Processed 3840/14702 samples.
# Processed 3968/14702 samples.
# Processed 4096/14702 samples.
# Processed 4224/14702 samples.
# Processed 4352/14702 samples.
# Processed 4480/14702 samples.
# Processed 4608/14702 samples.
# Processed 4736/14702 samples.
# Processed 4864/14702 samples.
# Processed 4992/14702 samples.
# Processed 5120/14702 samples.
# Processed 5248/14702 samples.
# Processed 5376/14702 samples.
# Processed 5504/14702 samples.
# Processed 5632/14702 samples.
# Processed 5760/14702 samples.
# Processed 5888/14702 samples.
# Processed 6016/14702 samples.
# Processed 6144/14702 samples.
# Processed 6272/14702 samples.
# Processed 6400/14702 samples.
# Processed 6528/14702 samples.
# Processed 6656/14702 samples.
# Processed 6784/14702 samples.
# Processed 6912/14702 samples.
# Processed 7040/14702 samples.
# Processed 7168/14702 samples.
# Processed 7296/14702 samples.
# Processed 7424/14702 samples.
# Processed 7552/14702 samples.
# Processed 7680/14702 samples.
# Processed 7808/14702 samples.
# Processed 7936/14702 samples.
# Processed 8064/14702 samples.
# Processed 8192/14702 samples.
# Processed 8320/14702 samples.
# Processed 8448/14702 samples.
# Processed 8576/14702 samples.
# Processed 8704/14702 samples.
# Processed 8832/14702 samples.
# Processed 8960/14702 samples.
# Processed 9088/14702 samples.
# Processed 9216/14702 samples.
# Processed 9344/14702 samples.
# Processed 9472/14702 samples.
# Processed 9600/14702 samples.
# Processed 9728/14702 samples.
# Processed 9856/14702 samples.
# Processed 9984/14702 samples.
# Processed 10112/14702 samples.
# Processed 10240/14702 samples.
# Processed 10368/14702 samples.
# Processed 10496/14702 samples.
# Processed 10624/14702 samples.
# Processed 10752/14702 samples.
# Processed 10880/14702 samples.
# Processed 11008/14702 samples.
# Processed 11136/14702 samples.
# Processed 11264/14702 samples.
# Processed 11392/14702 samples.
# Processed 11520/14702 samples.
# Processed 11648/14702 samples.
# Processed 11776/14702 samples.
# Processed 11904/14702 samples.
# Processed 12032/14702 samples.
# Processed 12160/14702 samples.
# Processed 12288/14702 samples.
# Processed 12416/14702 samples.
# Processed 12544/14702 samples.
# Processed 12672/14702 samples.
# Processed 12800/14702 samples.
# Processed 12928/14702 samples.
# Processed 13056/14702 samples.
# Processed 13184/14702 samples.
# Processed 13312/14702 samples.
# Processed 13440/14702 samples.
# Processed 13568/14702 samples.
# Processed 13696/14702 samples.
# Processed 13824/14702 samples.
# Processed 13952/14702 samples.
# Processed 14080/14702 samples.
# Processed 14208/14702 samples.
# Processed 14336/14702 samples.
# Processed 14464/14702 samples.
# Processed 14592/14702 samples.
# Processed 14720/14702 samples.
# Processed 14702/14702 samples.
# Done.

# %%
# write a few examples out to file
import tabulate
print(tabulate.tabulate(bart_results[[outputcol, outputcol]].sample(10), headers='keys', tablefmt='simple'))
# Out:
#        brief_hospital_course                                              brief_hospital_course
# -----  -----------------------------------------------------------------  -----------------------------------------------------------------
# 13534  Mrs. ___ was admitted to the neurology service for evaluation      Mrs. ___ was admitted to the neurology service for evaluation
#        of her diplopia. She had a brain MRI due to consideration of       of her diplopia. She had a brain MRI due to consideration of
#        brainstem stroke causing CN III dysfunction (especially in the     brainstem stroke causing CN III dysfunction (especially in the
#        setting of her family history and cardiovascular risk factors)     setting of her family history and cardiovascular risk factors)
#        and this did not show any explanation, including stroke, for her   and this did not show any explanation, including stroke, for her
#        vision problems. Therefore the most likely diagnosis became        vision problems. Therefore the most likely diagnosis became
#        myasethenia ___, though antibodies were pending at the time        myasethenia ___, though antibodies were pending at the time
#        of discharge. She was started on pyridostigmine on ___ at 30mg     of discharge. She was started on pyridostigmine on ___ at 30mg
#        without much improvement but on ___, after 60mg, she had some      without much improvement but on ___, after 60mg, she had some
#        subjective improvement her ability to read the subtitles of the    subjective improvement her ability to read the subtitles of the
#        TV and also improvement on exam. She was discharged home on        TV and also improvement on exam. She was discharged home on
#        pyridostigmine with the plan for referral to a neuromuscular       pyridostigmine with the plan for referral to a neuromuscular
#        specialist. She                                                    specialist. She
#
#        TRANSITIONAL ISSUES                                                TRANSITIONAL ISSUES
#        [] Atrius PCP must refer to neuromuscular specialist               [] Atrius PCP must refer to neuromuscular specialist
#        [] Follow up results from myasthenia ___ antibody results          [] Follow up results from myasthenia ___ antibody results
#        [] Take pyridostigmine 60mg TID until otherwise directed by your   [] Take pyridostigmine 60mg TID until otherwise directed by your
#        doctor                                                             doctor
#        [] Patch one eye, alternating, to improve your vision and          [] Patch one eye, alternating, to improve your vision and
#        ability to function for now                                        ability to function for now
#        [] Follow up with ___ pediatrician regarding your blood pressure   [] Follow up with ___ pediatrician regarding your blood pressure
#        management and your blood pressures were elevated during the       management and your blood pressures were elevated during the
#        hospitalization                                                    hospitalization
# 13136  ___ yo male with no known CAD who is admitted with 2 episodes of   ___ yo male with no known CAD who is admitted with 2 episodes of
#        chest pain which was persistent despite nitroglycerine drip and    chest pain which was persistent despite nitroglycerine drip and
#        morphine. He ruled out for MI with 3 sets of negative enzymes      morphine. He ruled out for MI with 3 sets of negative enzymes
#        and pain resolved spontaneously overnight. He had an exercise      and pain resolved spontaneously overnight. He had an exercise
#        stress test, which was normal, and patient was discharged pain     stress test, which was normal, and patient was discharged pain
#        free.                                                              free.
#        .                                                                  .
#  4447  This is a ___ year old male with past medical history of alcohol   This is a ___ year old male with past medical history of alcohol
#        use disorder, depression and anxiety, admitted ___                 use disorder, depression and anxiety, admitted ___
#        following fall off mountain bike with headstrike without helmet,   following fall off mountain bike with headstrike without helmet,
#        found to have bilateral vision loss of unclear etiology, course    found to have bilateral vision loss of unclear etiology, course
#        complicated by alcohol withdrawal treated with phenobarbitol,      complicated by alcohol withdrawal treated with phenobarbitol,
#        workup for vision findings without definite etiology, vision       workup for vision findings without definite etiology, vision
#        spontaneously resolving to normal, able to be discharged home.     spontaneously resolving to normal, able to be discharged home.
#
#        # BILATERAL VISION LOSS                                            # BILATERAL VISION LOSS
#        # Fall off a bike with headstrike                                  # Fall off a bike with headstrike
#        # LEFT TONIC PUPIL                                                 # LEFT TONIC PUPIL
#        Initially presented to ___ following falling off a bike            Initially presented to ___ following falling off a bike
#        with headstrike, with constellation of neurologic symptoms         with headstrike, with constellation of neurologic symptoms
#        including cranial nerve deficits, L sided weakness and vision      including cranial nerve deficits, L sided weakness and vision
#        loss. MRI spine without acute change.  MRI brain with orbits       loss. MRI spine without acute change.  MRI brain with orbits
#        showing some possible optic stranding thought to be due to         showing some possible optic stranding thought to be due to
#        traumatic or metabolic ___, though quality of image                traumatic or metabolic ___, though quality of image
#        was degraded due to motion.  Patient was seen by                   was degraded due to motion.  Patient was seen by
#        neuro-ophthalmology, who diagnosed Adie's tonic pupil.  His        neuro-ophthalmology, who diagnosed Adie's tonic pupil.  His
#        vision spontaneously resolved to normal.  A repeat MRI of brain    vision spontaneously resolved to normal.  A repeat MRI of brain
#        & orbits showed a better quality image with fat stranding in the   & orbits showed a better quality image with fat stranding in the
#        inferolateral aspect of the left optic nerve but no other          inferolateral aspect of the left optic nerve but no other
#        findings to suggest neuritis. Neuro-ophthalmology remained         findings to suggest neuritis. Neuro-ophthalmology remained
#        uncertain regarding etiology of presenting symptoms, raising       uncertain regarding etiology of presenting symptoms, raising
#        question of trauma versus intoxication.  Workup for alternate      question of trauma versus intoxication.  Workup for alternate
#        causes was pending at time of discharge. Patient to follow-up      causes was pending at time of discharge. Patient to follow-up
#        with neuro-ophthalmology.                                          with neuro-ophthalmology.
#
#        # Alcohol withdrawal                                               # Alcohol withdrawal
#        ___ hospital course complicated by alcohol withdrawal              ___ hospital course complicated by alcohol withdrawal
#        requiring phenobarbital load.  Wife reported patient has been      requiring phenobarbital load.  Wife reported patient has been
#        drinking ___ of vodka daily, although patient reported a           drinking ___ of vodka daily, although patient reported a
#        smaller amount. Required phenobarbital load 260mg IV x1 in ED,     smaller amount. Required phenobarbital load 260mg IV x1 in ED,
#        then rescue dose 130mg IV x1 in ICU on ___.  Additional            then rescue dose 130mg IV x1 in ICU on ___.  Additional
#        symptoms treated with prn clonidine.  He received thiamine 500     symptoms treated with prn clonidine.  He received thiamine 500
#        mg IV TID x3d and was discharged on PO thiamine, multivitamin      mg IV TID x3d and was discharged on PO thiamine, multivitamin
#        and folate. He was not very open to discussing his alcohol use     and folate. He was not very open to discussing his alcohol use
#        during this admission and minimized his alcohol intake             during this admission and minimized his alcohol intake
#        frequently ("a few too many barbecues.")--he declined assistance   frequently ("a few too many barbecues.")--he declined assistance
#        with quitting.                                                     with quitting.
#
#        # TRANSAMINITIS                                                    # TRANSAMINITIS
#        Admitted with ALT 85 AST 173 without additional LFT abnormality.   Admitted with ALT 85 AST 173 without additional LFT abnormality.
#         Suspected to be acute changes or chronic changes from his          Suspected to be acute changes or chronic changes from his
#        alcohol intake.  Viral hepatitis panel negative (does show HBV     alcohol intake.  Viral hepatitis panel negative (does show HBV
#        non-immunized). ALT 83 AST 114 at discharge.  Consider referral    non-immunized). ALT 83 AST 114 at discharge.  Consider referral
#        for cirrhosis evaluation as outpatient.                            for cirrhosis evaluation as outpatient.
#
#        # THROMBOCYTOPENIA                                                 # THROMBOCYTOPENIA
#        Admitted with platelets 89, nadir at 51 before improving to 59     Admitted with platelets 89, nadir at 51 before improving to 59
#        at discharge.                                                      at discharge.
#         In setting of significant alcohol intake as above, suspected to    In setting of significant alcohol intake as above, suspected to
#        be related to bone marrow suppression from alcohol.  Would         be related to bone marrow suppression from alcohol.  Would
#        consider workup as outpatient.                                     consider workup as outpatient.
#
#        # Mild intermittent ASTHMA                                         # Mild intermittent ASTHMA
#        Continued Advair and albuterol.                                    Continued Advair and albuterol.
#  8806  Mr. ___ is a ___ y/o male with a past medical history of ESRD      Mr. ___ is a ___ y/o male with a past medical history of ESRD
#        on HD (TTS), sCHF (EF 40% ___, HCV (untreated) cirrhosis,          on HD (TTS), sCHF (EF 40% ___, HCV (untreated) cirrhosis,
#        h/o hypocalcemia ___ parathyroidectomy, HTN, DM who presented      h/o hypocalcemia ___ parathyroidectomy, HTN, DM who presented
#        with AMS.                                                          with AMS.
#
#        # Acute metabolic encephalopathy: patient had acute AMS the        # Acute metabolic encephalopathy: patient had acute AMS the
#        morning of presentation and was reportedly unresponsive at his     morning of presentation and was reportedly unresponsive at his
#        nursing home. Symptoms were ultimately attributed to large right   nursing home. Symptoms were ultimately attributed to large right
#        pleural effusion and possible infection as his symptoms cleared    pleural effusion and possible infection as his symptoms cleared
#        with broad spectrum antibiotics and after thoracentesis and        with broad spectrum antibiotics and after thoracentesis and
#        chest tube placement. He also received lactulose and rifaximin     chest tube placement. He also received lactulose and rifaximin
#        for hepatic encephalopathy. His mental status quickly improved.    for hepatic encephalopathy. His mental status quickly improved.
#        Of note, he did have intermittent episodes of agitation which      Of note, he did have intermittent episodes of agitation which
#        was attributed to delirium.                                        was attributed to delirium.
#
#        # Pleural effusion, right: patient has a history of a right        # Pleural effusion, right: patient has a history of a right
#        pleural effusion that was attributed to hepatic hydrothorax        pleural effusion that was attributed to hepatic hydrothorax
#        and/or CHF. He underwent a thoracentesis in the ED by IP and 2L    and/or CHF. He underwent a thoracentesis in the ED by IP and 2L
#        fluid was drained and a chest tube was placed. He was started on   fluid was drained and a chest tube was placed. He was started on
#        vanc/zosyn. His pleural studies were suggestive of a lymphocytic   vanc/zosyn. His pleural studies were suggestive of a lymphocytic
#        exudate. This was attributed to transformation of a chronic        exudate. This was attributed to transformation of a chronic
#        transudative pleural effusion to an exudative effusion. Patient    transudative pleural effusion to an exudative effusion. Patient
#        has a history of LTBI and was briefly on respiratory precautions   has a history of LTBI and was briefly on respiratory precautions
#        while the ___ was pending. ___ was mildly elevated, but not high   while the ___ was pending. ___ was mildly elevated, but not high
#        enough to suggest TB. After discussion with the patient's son,     enough to suggest TB. After discussion with the patient's son,
#        he received INH therapy for LTBI in the past. Also was ruled out   he received INH therapy for LTBI in the past. Also was ruled out
#        for active TB in the past with negative AFBx3. Pleural studies     for active TB in the past with negative AFBx3. Pleural studies
#        grew GPCs (S. viridans) and he remained on vancomycin given lack   grew GPCs (S. viridans) and he remained on vancomycin given lack
#        of sensitivity data; will receive 1 more dose with HD on ___       of sensitivity data; will receive 1 more dose with HD on ___
#        to complete an ___XR also showed a right lung                      to complete an ___XR also showed a right lung
#        nodule. Pleural cytology was negative for malignant cells. CT      nodule. Pleural cytology was negative for malignant cells. CT
#        chest showed rounded opacity in right middle lobe, likely          chest showed rounded opacity in right middle lobe, likely
#        atelectasis but cannot r/o malignancy. Patient will have f/u in    atelectasis but cannot r/o malignancy. Patient will have f/u in
#        the IP to discuss further management of this effusion.             the IP to discuss further management of this effusion.
#
#        # HCV cirrhosis: patient had a liver biopsy in ___ with stage      # HCV cirrhosis: patient had a liver biopsy in ___ with stage
#        I-II fibrosis and a fibroscan in ___ with F4 severe                I-II fibrosis and a fibroscan in ___ with F4 severe
#        fibrosis. Per outpatient liver notes, patient most likely has      fibrosis. Per outpatient liver notes, patient most likely has
#        cirrhosis based on thrombocytopenia and INR elevation. Has been    cirrhosis based on thrombocytopenia and INR elevation. Has been
#        on rifaximin and lactulose. His lactulose and rifaximin were       on rifaximin and lactulose. His lactulose and rifaximin were
#        continued. His pleural effusion was attributed to a hepatic        continued. His pleural effusion was attributed to a hepatic
#        hydrothorax.                                                       hydrothorax.
#
#        # Right lung nodule: CXR showed a 4cm lung nodule. CT chest was    # Right lung nodule: CXR showed a 4cm lung nodule. CT chest was
#        performed and revealed rounded opacity in right middle lobe,       performed and revealed rounded opacity in right middle lobe,
#        likely atelectasis but cannot r/o malignancy. Pleural cytology     likely atelectasis but cannot r/o malignancy. Pleural cytology
#        was negative for malignant cells.                                  was negative for malignant cells.
#
#        CHRONIC ISSUES                                                     CHRONIC ISSUES
#        # ESRD on HD: TTS                                                  # ESRD on HD: TTS
#        # Hypocalcemia: continued calcium acetate per renal. Discontinue   # Hypocalcemia: continued calcium acetate per renal. Discontinue
#        calcium carbonate per renal.                                       calcium carbonate per renal.
#        # Hypothyroid: continue levothyroxine. TSH was mildly elevated     # Hypothyroid: continue levothyroxine. TSH was mildly elevated
#        however T4 was normal.                                             however T4 was normal.
#        # DM: SSI                                                          # DM: SSI
#        # Chronic pain: initially held gabapentin and restarted at a       # Chronic pain: initially held gabapentin and restarted at a
#        lower dose based on his renal function.                            lower dose based on his renal function.
#
#        # CODE STATUS: Full (confirmed with NH)                            # CODE STATUS: Full (confirmed with NH)
#        # CONTACT:  ___- guardian                                          # CONTACT:  ___- guardian
#        Relationship: son/guardian                                         Relationship: son/guardian
#        Phone number: ___                                                  Phone number: ___
#
#
#        TRANSITIONAL ISSUES                                                TRANSITIONAL ISSUES
#        ====================                                               ====================
#        - will have f/u in the ___ clinic to discuss long term             - will have f/u in the ___ clinic to discuss long term
#        management of his recurrent pleural effusion                       management of his recurrent pleural effusion
#        - f/u pending cx                                                   - f/u pending cx
#        - continue with HD on TTS schedule; will need to receive 1 more    - continue with HD on TTS schedule; will need to receive 1 more
#        dose of vancomycin (per HD sliding scale protocol).                dose of vancomycin (per HD sliding scale protocol).
#        - CT scan of chest showed rounded opacity in right middle lobe,    - CT scan of chest showed rounded opacity in right middle lobe,
#        which could represent atelectasis vs. malignancy; recommend        which could represent atelectasis vs. malignancy; recommend
#        followup chest CT in 3 months to reassess the right middle lobe    followup chest CT in 3 months to reassess the right middle lobe
#        opacity in order to exclude the possibility of malignancy at       opacity in order to exclude the possibility of malignancy at
#        this site.                                                         this site.
#  3694  Mr. ___ is a ___ yo man with progressive metastatic melanoma       Mr. ___ is a ___ yo man with progressive metastatic melanoma
#        after receiving IL-2 off protocol (given ___, who presented        after receiving IL-2 off protocol (given ___, who presented
#        with confusion x1 day on top of constitutional and FTT sx x 1      with confusion x1 day on top of constitutional and FTT sx x 1
#        month. Imaging revealed new metastatic lesion to the occipital     month. Imaging revealed new metastatic lesion to the occipital
#        lobe, along with worsening of known osseous, adrenal and           lobe, along with worsening of known osseous, adrenal and
#        pulmonary metastatic disease. His course was complicated by        pulmonary metastatic disease. His course was complicated by
#        suspected seizure and severe bone pain. He was started on          suspected seizure and severe bone pain. He was started on
#        steroids and anti-epileptics and underwent radiation to the        steroids and anti-epileptics and underwent radiation to the
#        spine. Per family meeting discussion, the patient was              spine. Per family meeting discussion, the patient was
#        transitioned to hospice care.                                      transitioned to hospice care.
#  1925  Mr. ___ is a ___ male with a history of HTN and                    Mr. ___ is a ___ male with a history of HTN and
#        HLD, who presents with 1 month of night sweats, malaise, and       HLD, who presents with 1 month of night sweats, malaise, and
#        weight loss, with blood cultures growing viridans strep,           weight loss, with blood cultures growing viridans strep,
#        admitted for infectious work-up and treatment of bacteremia.       admitted for infectious work-up and treatment of bacteremia.
#
#        # AORTIC VALVE ENDOCARDITIS | VIRIDANS STREP BACTEREMIA            # AORTIC VALVE ENDOCARDITIS | VIRIDANS STREP BACTEREMIA
#        Patient notes malaise and night sweats for 1 month, found by his   Patient notes malaise and night sweats for 1 month, found by his
#        primary care physician to be bacteremic and referred to the        primary care physician to be bacteremic and referred to the
#        ___ ED. Initially started on vancomycin IV, switched to            ___ ED. Initially started on vancomycin IV, switched to
#        ceftriaxone IV on HD2 after outpatient and ED blood cultures       ceftriaxone IV on HD2 after outpatient and ED blood cultures
#        speciated to pan-sensitive viridans streptococci. CXR and CT       speciated to pan-sensitive viridans streptococci. CXR and CT
#        chest showed no acute cardiopulmonary process, CTAP showed         chest showed no acute cardiopulmonary process, CTAP showed
#        splenomegaly but no mass/abscess/adenopathy. He has had multiple   splenomegaly but no mass/abscess/adenopathy. He has had multiple
#        procedures to his gums in the past, though none recently, hence    procedures to his gums in the past, though none recently, hence
#        possible gingival source. TTE negative, TEE identified small       possible gingival source. TTE negative, TEE identified small
#        vegetation on aortic valve with moderate aortic regurgitation      vegetation on aortic valve with moderate aortic regurgitation
#        without any abscesses. Blood cultures cleared rapidly on           without any abscesses. Blood cultures cleared rapidly on
#        ceftriaxone, and per ID, the plan is to complete at least 4        ceftriaxone, and per ID, the plan is to complete at least 4
#        weeks of ceftriaxone 2g IV Q24h for the treatment of               weeks of ceftriaxone 2g IV Q24h for the treatment of
#        pan-sensitive S. viridans aortic valve endocarditis. PICC was      pan-sensitive S. viridans aortic valve endocarditis. PICC was
#        placed prior to discharge to enable to him to complete             placed prior to discharge to enable to him to complete
#        antibiotic course as an outpatient with home infusions.            antibiotic course as an outpatient with home infusions.
#
#        # THYROID NODULE                                                   # THYROID NODULE
#        Patient describes vague discomfort after swallowing but denies     Patient describes vague discomfort after swallowing but denies
#        odynophagia, halitosis, or reflux symptoms. Thyroid ultrasound     odynophagia, halitosis, or reflux symptoms. Thyroid ultrasound
#        on HD1 showed possible ectopic nodule, biopsied by FNA on HD2.     on HD1 showed possible ectopic nodule, biopsied by FNA on HD2.
#        The report of the FNA was pending on discharge, but per            The report of the FNA was pending on discharge, but per
#        discussion with the pathologist there were some atypical cells.    discussion with the pathologist there were some atypical cells.
#        The patient was notified prior to discharge, as was his primary    The patient was notified prior to discharge, as was his primary
#        care physician, with plan for close follow-up of pathology by      care physician, with plan for close follow-up of pathology by
#        the primary team and his primary care physician. His primary       the primary team and his primary care physician. His primary
#        care physician ___ agreed to make referral to                      care physician ___ agreed to make referral to
#        endocrinology/endocrine surgery pending final pathology results.   endocrinology/endocrine surgery pending final pathology results.
#        Of note, labs on HD1 show TSH 0.03 with T3 154 and free T4 1.8;    Of note, labs on HD1 show TSH 0.03 with T3 154 and free T4 1.8;
#        repeat TSH and peripheral markers after recovery from bacteremia   repeat TSH and peripheral markers after recovery from bacteremia
#        and/or at the discretion of endocrinology/endocrine surgery        and/or at the discretion of endocrinology/endocrine surgery
#        advised.                                                           advised.
#
#        # GLOBUS SENSATION                                                 # GLOBUS SENSATION
#        Patient describes vague sensation of fullness in his throat,       Patient describes vague sensation of fullness in his throat,
#        typically after eating, though not universally, prompting          typically after eating, though not universally, prompting
#        thyroid ultrasound as above. ___ consider further work-up should   thyroid ultrasound as above. ___ consider further work-up should
#        symptoms not resolve with endocrine/endocrine surgery evaluation   symptoms not resolve with endocrine/endocrine surgery evaluation
#        as above.                                                          as above.
#
#        # HEEL PAIN                                                        # HEEL PAIN
#        Patient presented during episode of severe right Achilles tendon   Patient presented during episode of severe right Achilles tendon
#        pain similar to episodes he has had in past. X-ray in ED showed    pain similar to episodes he has had in past. X-ray in ED showed
#        point calcifications. Pain thought to be due to calcific           point calcifications. Pain thought to be due to calcific
#        tendonitis, managed with ibuprofen and tramadol in hospital,       tendonitis, managed with ibuprofen and tramadol in hospital,
#        with symptomatic improvement. He was pain-free and ambulatory at   with symptomatic improvement. He was pain-free and ambulatory at
#        discharge.                                                         discharge.
#
#        # NORMOCYTIC ANEMIA                                                # NORMOCYTIC ANEMIA
#        Hgb of 10.3-11.1, down from 12.6 in ___, likely in the             Hgb of 10.3-11.1, down from 12.6 in ___, likely in the
#        setting of infection (though iron studies not entirely             setting of infection (though iron studies not entirely
#        consistent with chronic inflammation) or early iron deficiency.    consistent with chronic inflammation) or early iron deficiency.
#        SPEP/UPEP and SIFE/UIFE without specific abnormalities or          SPEP/UPEP and SIFE/UIFE without specific abnormalities or
#        monoclonal protein. There were no overt signs of hemolysis,        monoclonal protein. There were no overt signs of hemolysis,
#        without schistocytosis on peripheral smear. On review of           without schistocytosis on peripheral smear. On review of
#        peripheral smear with the hematology fellow, there were no overt   peripheral smear with the hematology fellow, there were no overt
#        signs of hematologic malignancy, but some atypical lymphocytes     signs of hematologic malignancy, but some atypical lymphocytes
#        seen, likely in the setting of infection; however, given mild      seen, likely in the setting of infection; however, given mild
#        nonspecific elevation in beta 2 microglobulin and mildly           nonspecific elevation in beta 2 microglobulin and mildly
#        enlarged spleen (likely in the setting of infection), repeat       enlarged spleen (likely in the setting of infection), repeat
#        peripheral smear and abdominal ultrasound advised following        peripheral smear and abdominal ultrasound advised following
#        resolution of infection, discussed with Dr. ___.                   resolution of infection, discussed with Dr. ___.
#
#        # SPLENOMEGALY                                                     # SPLENOMEGALY
#        Found incidentally to have mildly enlarged spleen on CT            Found incidentally to have mildly enlarged spleen on CT
#        abdomen/pelvis as above, likely in the setting of infection. CT    abdomen/pelvis as above, likely in the setting of infection. CT
#        torso without adenopathy, and LDH within normal limits. LFTs       torso without adenopathy, and LDH within normal limits. LFTs
#        within normal limits, and liver normal-appearing on CT             within normal limits, and liver normal-appearing on CT
#        abdomen/pelvis. As above, repeat peripheral smear and abdominal    abdomen/pelvis. As above, repeat peripheral smear and abdominal
#        ultrasound advised following resolution of infection.              ultrasound advised following resolution of infection.
#
#        # BLADDER WALL THICKENING/HEMATURIA                                # BLADDER WALL THICKENING/HEMATURIA
#        Found incidentally to have mild wall thickening of the anterior    Found incidentally to have mild wall thickening of the anterior
#        bladder that may be reactive or inflammatory, no definite          bladder that may be reactive or inflammatory, no definite
#        evidence of mass on CT abdomen/pelvis. Also with prostatic         evidence of mass on CT abdomen/pelvis. Also with prostatic
#        enlargement. UA without evidence of infection, but with small      enlargement. UA without evidence of infection, but with small
#        blood and 4 RBC. Repeat UA and consideration of cystoscopy         blood and 4 RBC. Repeat UA and consideration of cystoscopy
#        advised as an outpatient, discussed with Dr. ___.                  advised as an outpatient, discussed with Dr. ___.
#
#        # MALAISE/NIGHT SWEATS                                             # MALAISE/NIGHT SWEATS
#        Patient describes malaise and weight loss, as well as night        Patient describes malaise and weight loss, as well as night
#        sweats, with no overt fevers over a period of weeks, likely in     sweats, with no overt fevers over a period of weeks, likely in
#        the setting of subacute bacterial endocarditis. LDH normal, and    the setting of subacute bacterial endocarditis. LDH normal, and
#        CT torso without adenopathy or overt signs of malignancy, though   CT torso without adenopathy or overt signs of malignancy, though
#        repeat peripheral smear, abdominal ultrasound, and repeat          repeat peripheral smear, abdominal ultrasound, and repeat
#        UA/consideration of cystoscopy advised as above. He is without     UA/consideration of cystoscopy advised as above. He is without
#        clear risk factors for TB or suggestive radiographic findings.     clear risk factors for TB or suggestive radiographic findings.
#        Low suspicion for temporal arteritis in the absence of overt       Low suspicion for temporal arteritis in the absence of overt
#        fevers or headaches, jaw claudication, or scalp/TA tenderness.     fevers or headaches, jaw claudication, or scalp/TA tenderness.
#
#        # HYPERTENSION                                                     # HYPERTENSION
#        Continued home hydrochlorothiazide.                                Continued home hydrochlorothiazide.
#
#        # HYPERLIPIDEMIA                                                   # HYPERLIPIDEMIA
#        Continued home rosuvastatin.                                       Continued home rosuvastatin.
#  1914  The patient presented to Emergency Department on ___ with          The patient presented to Emergency Department on ___ with
#        a left groin graft abscess. Given findings, the patient was        a left groin graft abscess. Given findings, the patient was
#        taken to the operating room for a washout. There were no adverse   taken to the operating room for a washout. There were no adverse
#        events in the operating room; please see the operative note for    events in the operating room; please see the operative note for
#        details.  Patient was extubated, taken to the PACU until stable,   details.  Patient was extubated, taken to the PACU until stable,
#        then transferred to the ward for observation.                      then transferred to the ward for observation.
#
#        Neuro: The patient was alert and oriented throughout               Neuro: The patient was alert and oriented throughout
#        hospitalization; pain was well controlled with oxycodone and       hospitalization; pain was well controlled with oxycodone and
#        acetaminophen.                                                     acetaminophen.
#
#        CV: The patient remained stable from a cardiovascular              CV: The patient remained stable from a cardiovascular
#        standpoint; vital signs were routinely monitored. The patient      standpoint; vital signs were routinely monitored. The patient
#        also underwent an echocardiogram that was negative for             also underwent an echocardiogram that was negative for
#        vegetations.                                                       vegetations.
#
#        Pulmonary: The patient remained stable from a pulmonary            Pulmonary: The patient remained stable from a pulmonary
#        standpoint; vital signs were routinely monitored. Good pulmonary   standpoint; vital signs were routinely monitored. Good pulmonary
#        toilet, early ambulation and incentive spirometry were             toilet, early ambulation and incentive spirometry were
#        encouraged throughout hospitalization.                             encouraged throughout hospitalization.
#
#        GI/GU/FEN: The patient was tolerating a regular diet. Patient's    GI/GU/FEN: The patient was tolerating a regular diet. Patient's
#        intake and output were closely monitored                           intake and output were closely monitored
#
#        ID: The patient's fever curves were closely watched for signs of   ID: The patient's fever curves were closely watched for signs of
#        infection. Patient's blood cultures from his presentation to the   infection. Patient's blood cultures from his presentation to the
#        emergency department grew gram                                     emergency department grew gram
#        MRSA and strep anginosus and for this reason patient was started   MRSA and strep anginosus and for this reason patient was started
#        on vancomycin. Infectious disease was consulted and they           on vancomycin. Infectious disease was consulted and they
#        recommended a six week course of IV vancomycin. For this reason    recommended a six week course of IV vancomycin. For this reason
#        the patient had a PICC line inserted in order to be able to        the patient had a PICC line inserted in order to be able to
#        continue treatment as an outpatient. The patient's course of       continue treatment as an outpatient. The patient's course of
#        vancomycin should continue until ___.                              vancomycin should continue until ___.
#
#        HEME: The patient's blood counts were closely watched for signs    HEME: The patient's blood counts were closely watched for signs
#        of bleeding, of which there were none.                             of bleeding, of which there were none.
#
#        MSK: During this hospital course the patient complained of right   MSK: During this hospital course the patient complained of right
#        shoulder pain. An MRI was obtained and orthopedic surgery was      shoulder pain. An MRI was obtained and orthopedic surgery was
#        consulted. The patient's pain responded to naproxen.               consulted. The patient's pain responded to naproxen.
#
#        Prophylaxis: The patient received heparin that was then            Prophylaxis: The patient received heparin that was then
#        discontinued and the patient was restarted on xarelto. ___ dyne    discontinued and the patient was restarted on xarelto. ___ dyne
#        boots were used during this stay and was encouraged to get up      boots were used during this stay and was encouraged to get up
#        and ambulate as early as possible.                                 and ambulate as early as possible.
#
#        At the time of discharge, the patient was doing well, afebrile     At the time of discharge, the patient was doing well, afebrile
#        and hemodynamically stable.  The patient was tolerating a diet,    and hemodynamically stable.  The patient was tolerating a diet,
#        ambulating, voiding without assistance, and pain was well          ambulating, voiding without assistance, and pain was well
#        controlled.  The patient received discharge teaching and           controlled.  The patient received discharge teaching and
#        follow-up instructions with understanding verbalized and           follow-up instructions with understanding verbalized and
#        agreement with the discharge plan.                                 agreement with the discharge plan.
#   295  Ms. ___ is a ___ woman with a history notable                      Ms. ___ is a ___ woman with a history notable
#        for hypertension, hyperlipidemia who presented to the ED with a    for hypertension, hyperlipidemia who presented to the ED with a
#        transient episode of anterograde amnesia, consistent with          transient episode of anterograde amnesia, consistent with
#        transient global amnesia. She returned to her neurological         transient global amnesia. She returned to her neurological
#        baseline within 24 hours. She reported a chronic headache over     baseline within 24 hours. She reported a chronic headache over
#        the past few months which responded to Tylenol. During her         the past few months which responded to Tylenol. During her
#        hospitalization she developed fever x1 to 102 and had continued    hospitalization she developed fever x1 to 102 and had continued
#        headache. Her work-up included multiple imaging findings which     headache. Her work-up included multiple imaging findings which
#        showed no acute disease as well as CSF analysis which revealed a   showed no acute disease as well as CSF analysis which revealed a
#        mild pleocytosis (WBC of 6) as well as influenza B positive. She   mild pleocytosis (WBC of 6) as well as influenza B positive. She
#        was treated with broad-spectrum antibiotics for presumed           was treated with broad-spectrum antibiotics for presumed
#        meningitis and acyclovir for suspicion of HSV encephalitis,        meningitis and acyclovir for suspicion of HSV encephalitis,
#        which were discontinued after laboratory studies failed to show    which were discontinued after laboratory studies failed to show
#        any pathogen growth on culture or PCR, she was also treated with   any pathogen growth on culture or PCR, she was also treated with
#        oseltamivir for her influenza infection. During her                oseltamivir for her influenza infection. During her
#        hospitalization her symptoms gradually improved, and she was       hospitalization her symptoms gradually improved, and she was
#        discharged home in hemodynamically stable condition. Her home      discharged home in hemodynamically stable condition. Her home
#        medications were continued unchanged.                              medications were continued unchanged.
#
#        # TGA vs Viral Encephalitis - presentation more classic for TGA,   # TGA vs Viral Encephalitis - presentation more classic for TGA,
#        there was rapid resolution of amnesia within 12 hours and this     there was rapid resolution of amnesia within 12 hours and this
#        time course suggests against encephalitis. However, we would not   time course suggests against encephalitis. However, we would not
#        expect to see a pleiocytosis in the CSF with TGA. It is possible   expect to see a pleiocytosis in the CSF with TGA. It is possible
#        that this could have been from influenza itself; it is unknown     that this could have been from influenza itself; it is unknown
#        if influenza infection causes a pleiocytosis when there is no      if influenza infection causes a pleiocytosis when there is no
#        evidence of meningoencephalitis.                                   evidence of meningoencephalitis.
#        - MRI w/o evidence of infarct, mass or hemorrhage                  - MRI w/o evidence of infarct, mass or hemorrhage
#        - CTA H&N without vasculitis or acute lesion                       - CTA H&N without vasculitis or acute lesion
#        - CSF w 6 WBCs, normal glucose, normal protein                     - CSF w 6 WBCs, normal glucose, normal protein
#        - s/p acyclovir for HSV prophylaxis, DC'd after PCR negative       - s/p acyclovir for HSV prophylaxis, DC'd after PCR negative
#        - s/p broad spectrum abx for bacterial meningitis, DC'd after      - s/p broad spectrum abx for bacterial meningitis, DC'd after
#        culture/ ___ neg                                                   culture/ ___ neg
#
#        #Influenza                                                         #Influenza
#        - Patient started on Tamiflu ___ within 48 hours of                - Patient started on Tamiflu ___ within 48 hours of
#        symptom onset. She should complete a 5 day course, which will      symptom onset. She should complete a 5 day course, which will
#        conclude on ___.                                                   conclude on ___.
#
#        # Hypertension                                                     # Hypertension
#        - continue atenolol/chlorthalidone                                 - continue atenolol/chlorthalidone
#
#        # Hyperlipidemia                                                   # Hyperlipidemia
#        - continue atorvastatin 20                                         - continue atorvastatin 20
#
#        # Mood disorder                                                    # Mood disorder
#        - continue paroxetine 20 qd                                        - continue paroxetine 20 qd
#
#        Transitional Issues                                                Transitional Issues
#        - follow up in neurology clinic                                    - follow up in neurology clinic
#  8085  Mr. ___ presented to the Emergency Department on ___ on            Mr. ___ presented to the Emergency Department on ___ on
#        referral from the outpatient vascular surgery clinic with left     referral from the outpatient vascular surgery clinic with left
#        lower extremity ischemia with                                      lower extremity ischemia with
#        ulcer and failing vein graft. On ___ he was taken to the           ulcer and failing vein graft. On ___ he was taken to the
#        endovascular suite for a left lower extremity angiogram, with      endovascular suite for a left lower extremity angiogram, with
#        angioplasty of the ___ bypass and distal ___. On ___, he           angioplasty of the ___ bypass and distal ___. On ___, he
#        was taken by podiatry to the OR for a left foot sesamoidectomy     was taken by podiatry to the OR for a left foot sesamoidectomy
#        and debridement. He was given broad spectrum antibiotics for his   and debridement. He was given broad spectrum antibiotics for his
#        left foot wound as well as his left anterior shin wound which      left foot wound as well as his left anterior shin wound which
#        appeared infected. Given that he had several areas of stenosis     appeared infected. Given that he had several areas of stenosis
#        from his vein bypass and had several areas of ischemia by          from his vein bypass and had several areas of ischemia by
#        angiography, and that the angioplasty of the vein graft was not    angiography, and that the angioplasty of the vein graft was not
#        successful, he was taken to the OR on ___ for interposition        successful, he was taken to the OR on ___ for interposition
#        graft revascularization from a good portion of the old bypass      graft revascularization from a good portion of the old bypass
#        graft to the distal posterior tibial artery just above the         graft to the distal posterior tibial artery just above the
#        ankle. See operative report for details. This procedure            ankle. See operative report for details. This procedure
#        successfully restored blood flow to his left lower extremity and   successfully restored blood flow to his left lower extremity and
#        he has strong ___ signals on the left and a palpable graft. He     he has strong ___ signals on the left and a palpable graft. He
#        recovered from this procedure well, was ambulating with physical   recovered from this procedure well, was ambulating with physical
#        therapy and cleared for discharge home, tolerating a regular       therapy and cleared for discharge home, tolerating a regular
#        diet. His left foot was managed by podiatric surgery with wound    diet. His left foot was managed by podiatric surgery with wound
#        vac changes regularly. Per the podiatry team and pathology         vac changes regularly. Per the podiatry team and pathology
#        reports, he had acute on chronic osteomyelitis which had been      reports, he had acute on chronic osteomyelitis which had been
#        successfully removed by their operation. He was continued on       successfully removed by their operation. He was continued on
#        antibiotics and regular dressing changes for a left anterior       antibiotics and regular dressing changes for a left anterior
#        shin wound that put out yellow/green exudate. He was discharged    shin wound that put out yellow/green exudate. He was discharged
#        on oral antibiotics with close follow up to monitor his wound      on oral antibiotics with close follow up to monitor his wound
#        and his recent surgery.                                            and his recent surgery.
#
#        As for a systems based review of his hospitalization:              As for a systems based review of his hospitalization:
#
#        Neuro: The patient was alert and oriented throughout               Neuro: The patient was alert and oriented throughout
#        hospitalization; pain was managed well with oral pain              hospitalization; pain was managed well with oral pain
#        medications once tolerating a diet.                                medications once tolerating a diet.
#
#        CV: The patient remained stable from a cardiovascular              CV: The patient remained stable from a cardiovascular
#        standpoint; vital signs were routinely monitored.                  standpoint; vital signs were routinely monitored.
#
#        Pulmonary: The patient remained stable from a pulmonary            Pulmonary: The patient remained stable from a pulmonary
#        standpoint; vital signs were routinely monitored. Good pulmonary   standpoint; vital signs were routinely monitored. Good pulmonary
#        toilet, early ambulation and incentive spirometry were             toilet, early ambulation and incentive spirometry were
#        encouraged throughout hospitalization.                             encouraged throughout hospitalization.
#
#        GI/GU/FEN: Patient's diet was generally a Regular diet, which      GI/GU/FEN: Patient's diet was generally a Regular diet, which
#        was well tolerated. Patient's intake and output were closely       was well tolerated. Patient's intake and output were closely
#        monitored. He did have an increase in his creatinine to 1.3        monitored. He did have an increase in his creatinine to 1.3
#        (baseline 1.1) on ___, with a FENa of 0.8%. He received            (baseline 1.1) on ___, with a FENa of 0.8%. He received
#        500cc isotonic fluids, and the following day his Cr increased to   500cc isotonic fluids, and the following day his Cr increased to
#        1.5, and the next day to 1.6. His FENa was checked again which     1.5, and the next day to 1.6. His FENa was checked again which
#        was 0.5%, so he was thought to have prerenal elevation in          was 0.5%, so he was thought to have prerenal elevation in
#        creatinine and was given multiple LR fluid boluses, which          creatinine and was given multiple LR fluid boluses, which
#        resulted in a downtrending of his creatinine down to 1.3 on the    resulted in a downtrending of his creatinine down to 1.3 on the
#        day of discharge. During this entire course, he had been making    day of discharge. During this entire course, he had been making
#        adequate and ample urine output.                                   adequate and ample urine output.
#
#        ID: The patient's fever curves were closely watched for signs of   ID: The patient's fever curves were closely watched for signs of
#        infection, of which there were none. He was treated on broad       infection, of which there were none. He was treated on broad
#        spectrum antibiotics (vanc, levofloxacin, flagyl) for his left     spectrum antibiotics (vanc, levofloxacin, flagyl) for his left
#        lower extremity wound, and was discharged on PO Bactrim. The       lower extremity wound, and was discharged on PO Bactrim. The
#        single positive culture data on record was mixed bacterial flora   single positive culture data on record was mixed bacterial flora
#        from the left foot that included MSSA. Blood cultures drawn on     from the left foot that included MSSA. Blood cultures drawn on
#        ___ were negative.                                                 ___ were negative.
#
#        HEME: The patient's blood counts were closely watched for signs    HEME: The patient's blood counts were closely watched for signs
#        of bleeding. He did require 2 units of blood after his bypass      of bleeding. He did require 2 units of blood after his bypass
#        procedure for a Hb<7.0. He had some slow bleeding from the vein    procedure for a Hb<7.0. He had some slow bleeding from the vein
#        graft site at the right arm which resulted in arm swelling,        graft site at the right arm which resulted in arm swelling,
#        which was managed by holding anticoagulation and wrapping the      which was managed by holding anticoagulation and wrapping the
#        arm in an ACE bandage. This resulted in stability and              arm in an ACE bandage. This resulted in stability and
#        improvement of the right arm swelling, as well as a                improvement of the right arm swelling, as well as a
#        stabilization of his hemoglobin and hematocrit.                    stabilization of his hemoglobin and hematocrit.
#
#        Prophylaxis: The patient had been on a heparin gtt during the      Prophylaxis: The patient had been on a heparin gtt during the
#        admission which was held when he had the above bleeding events.    admission which was held when he had the above bleeding events.
#        The decision was made to hold heparin and start low dose Xarelto   The decision was made to hold heparin and start low dose Xarelto
#        two days after discharge.                                          two days after discharge.
#
#        At the time of discharge, the patient was doing well, afebrile     At the time of discharge, the patient was doing well, afebrile
#        and hemodynamically stable.  The patient was tolerating a diet,    and hemodynamically stable.  The patient was tolerating a diet,
#        ambulating, voiding without assistance, and pain was well          ambulating, voiding without assistance, and pain was well
#        controlled.  The patient received discharge teaching and           controlled.  The patient received discharge teaching and
#        follow-up instructions with understanding verbalized and           follow-up instructions with understanding verbalized and
#        agreement with the discharge plan.                                 agreement with the discharge plan.
#  2376  Mr. ___ is a ___ year old male with Atrial fibrillation,           Mr. ___ is a ___ year old male with Atrial fibrillation,
#        PPM/ICD placement, CAD s/p 3 previous MIs, Systolic CHF with EF    PPM/ICD placement, CAD s/p 3 previous MIs, Systolic CHF with EF
#        ___, prior stroke with residual right sided weakness who           ___, prior stroke with residual right sided weakness who
#        presents with dyspnea on exertion.                                 presents with dyspnea on exertion.
#
#        active issue:                                                      active issue:
#
#        # Acute on chronic systolic CHF Exacerbation: MI was ruled out     # Acute on chronic systolic CHF Exacerbation: MI was ruled out
#        via serial cardiac enzymes and EKGs. TTE was essentially           via serial cardiac enzymes and EKGs. TTE was essentially
#        unchanged from prior with an EF of 30%. He was diuresed with       unchanged from prior with an EF of 30%. He was diuresed with
#        furosemide 60mg iv daily for three days. Digoxin was continued.    furosemide 60mg iv daily for three days. Digoxin was continued.
#        Home lasix increased from 40mg daily to 60mg daily to be take at   Home lasix increased from 40mg daily to 60mg daily to be take at
#        the high dose only during this gout flare/prednisone taper.        the high dose only during this gout flare/prednisone taper.
#        Lisinopril, which he had not taken for some time, was started at   Lisinopril, which he had not taken for some time, was started at
#        half the prior dose (from 40mg daily to 20mg daily). The reason    half the prior dose (from 40mg daily to 20mg daily). The reason
#        for having stopped lisinopril in the past was hyperkalemia; it     for having stopped lisinopril in the past was hyperkalemia; it
#        seems he was also on spironolactone at that time. His admission    seems he was also on spironolactone at that time. His admission
#        weight was 94.3kg. His discharge weight was x.                     weight was 94.3kg. His discharge weight was x.
#
#        # Gout flare: He was noted to have his typical manifestations of   # Gout flare: He was noted to have his typical manifestations of
#        gout in his left elbow and right thumb on hospital day 3. He was   gout in his left elbow and right thumb on hospital day 3. He was
#        discharged on a prednisone taper.                                  discharged on a prednisone taper.
#
#        chronic issues:                                                    chronic issues:
#
#        # CAD: Continued aspirin and carvedilol. Restarted lisinopril as   # CAD: Continued aspirin and carvedilol. Restarted lisinopril as
#        explained above.                                                   explained above.
#
#        # Atrial Fibrillation: Aspirin and beta blockade continued.        # Atrial Fibrillation: Aspirin and beta blockade continued.
#        Coumadin continued at his home dose after one dose was held on     Coumadin continued at his home dose after one dose was held on
#        hospital day one for an INR of 3.2. INR upon discharge was 2.0.    hospital day one for an INR of 3.2. INR upon discharge was 2.0.
#
#        # DM2: Metformin was held while in house, and he was maintained    # DM2: Metformin was held while in house, and he was maintained
#        on an insulin sliding scale. Metformin restarted upon discharge.   on an insulin sliding scale. Metformin restarted upon discharge.
#
#        - Hold Metformin                                                   - Hold Metformin
#        - ___ QACHS                                                        - ___ QACHS
#        - HISS                                                             - HISS
#
#        # CKD: Stable on admission with mild increase upon iv diuresis.    # CKD: Stable on admission with mild increase upon iv diuresis.
#        Creatinine corrected back to relative baseline of 1.5 on           Creatinine corrected back to relative baseline of 1.5 on
#        admission.                                                         admission.
#
#        # FEN: No IVF, replete electrolytes, cardiac Low Na diet           # FEN: No IVF, replete electrolytes, cardiac Low Na diet
#        # Prophylaxis: Subcutaneous heparin                                # Prophylaxis: Subcutaneous heparin
#        # Access: peripherals                                              # Access: peripherals
#        # Communication: ___: ___                                          # Communication: ___: ___
#        # Code: Full code                                                  # Code: Full code

# %%
with open('sample_BART_results_v1.txt', 'w') as f:
    f.write(tabulate.tabulate(bart_results[[outputcol, f"{outputcol}_BART"]].sample(10), headers='keys', tablefmt='simple'))
